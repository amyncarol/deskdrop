# %%
import pandas as pd
import math
import scipy
import numpy as np
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from numpy.linalg import norm
from surprise import Dataset, Reader
from surprise.model_selection import cross_validate
from surprise import NormalPredictor, BaselineOnly, KNNBasic, KNNWithMeans, KNNWithZScore, KNNBaseline, SVD, NMF

# %%
articles = pd.read_csv('shared_articles.csv')
articles = articles[articles['eventType']=='CONTENT SHARED']
articles.shape
# Out:
# (3047, 13)

# %%
articles.head(1)
# Out:
#     timestamp       eventType            contentId       authorPersonId  \
# 1  1459193988  CONTENT SHARED -4110354420726924665  4340306774493623681
#
#        authorSessionId authorUserAgent authorRegion authorCountry contentType  \
# 1  8940341205206233829             NaN          NaN           NaN        HTML
#
#                                                  url  \
# 1  http://www.nytimes.com/2016/03/28/business/dea...
#
#                                                title  \
# 1  Ethereum, a Virtual Currency, Enables Transact...
#
#                                                 text lang
# 1  All of this work is still very early. The firs...   en

# %%
iteractions = pd.read_csv('users_interactions.csv')
iteractions.shape
# Out:
# (72312, 8)

# %%
iteractions.head()
# Out:
#     timestamp eventType            contentId             personId  \
# 0  1465413032      VIEW -3499919498720038879 -8845298781299428018
# 1  1465412560      VIEW  8890720798209849691 -1032019229384696495
# 2  1465416190      VIEW   310515487419366995 -1130272294246983140
# 3  1465413895    FOLLOW   310515487419366995   344280948527967603
# 4  1465412290      VIEW -7820640624231356730  -445337111692715325
#
#              sessionId                                          userAgent  \
# 0  1264196770339959068                                                NaN
# 1  3621737643587579081  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 2  2631864456530402479                                                NaN
# 3 -3167637573980064150                                                NaN
# 4  5611481178424124714                                                NaN
#
#   userRegion userCountry
# 0        NaN         NaN
# 1         NY          US
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %%
iteractions.personId.unique().shape
# Out:
# (1895,)

# %%
iteractions.contentId.unique().shape
# Out:
# (2987,)

# %%
iteractions.eventType.unique()
# Out:
# array(['VIEW', 'FOLLOW', 'BOOKMARK', 'LIKE', 'COMMENT CREATED'],
#       dtype=object)

# %%
event_type_strength = {
   'VIEW': 1.0,
   'LIKE': 2.0, 
   'BOOKMARK': 2.5, 
   'FOLLOW': 3.0,
   'COMMENT CREATED': 4.0,  
}

iteractions.eventType = iteractions.eventType.apply(lambda x:event_type_strength[x])
iteractions.head(1)
# Out:
#     timestamp  eventType            contentId             personId  \
# 0  1465413032        1.0 -3499919498720038879 -8845298781299428018
#
#              sessionId userAgent userRegion userCountry
# 0  1264196770339959068       NaN        NaN         NaN

# %%
# iteraction_count_by_user = iteractions.groupby('personId').size()
# users_with_enough_count = iteraction_count_by_user[iteraction_count_by_user>=5]
# users_with_enough_count = users_with_enough_count.reset_index()
# users_with_enough_count.personId.unique().shape

# %%
iteractions = iteractions.groupby(['personId', 'contentId'])['eventType'].sum().apply(lambda x:math.log(1+x, 2)).reset_index()

# %%
activity_count = iteractions.groupby('personId').size().reset_index()
active_user = activity_count[activity_count.iloc[:, 1]>=5]
iteractions = pd.merge(iteractions, active_user, how = 'right', on='personId').drop(0, axis = 1)

# %%
iteractions.head()
# Out:
#               personId            contentId  eventType
# 0 -9223121837663643404 -8949113594875411859   1.000000
# 1 -9223121837663643404 -8377626164558006982   1.000000
# 2 -9223121837663643404 -8208801367848627943   1.000000
# 3 -9223121837663643404 -8187220755213888616   1.000000
# 4 -9223121837663643404 -7423191370472335463   3.169925

# %%
iteractions.contentId.unique().shape
# Out:
# (2984,)

# %%
iteractions.personId.unique().shape
# Out:
# (1140,)

# %%
reader = Reader(rating_scale=(1, 4))
data = Dataset.load_from_df(iteractions[['personId', 'contentId', 'eventType']], reader)

# %%
cross_validate(NormalPredictor(), data, cv=3, verbose=True)
cross_validate(BaselineOnly(), data, cv=3, verbose=True)
cross_validate(KNNBasic(), data, cv=3, verbose=True)
cross_validate(KNNWithMeans(), data, cv=3, verbose=True)
cross_validate(KNNWithZScore(), data, cv=3, verbose=True)
cross_validate(KNNBaseline(), data, cv=3, verbose=True)
cross_validate(SVD(), data, cv=3, verbose=True)
cross_validate(NMF(), data, cv=3, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm NormalPredictor on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.8826  0.8753  0.8767  0.8782  0.0032
# MAE (testset)     0.6526  0.6515  0.6479  0.6507  0.0020
# Fit time          0.07    0.04    0.04    0.05    0.01
# Test time         0.10    0.17    0.14    0.14    0.03
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Evaluating RMSE, MAE of algorithm BaselineOnly on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.6224  0.6207  0.6280  0.6237  0.0031
# MAE (testset)     0.4668  0.4664  0.4704  0.4679  0.0018
# Fit time          0.10    0.08    0.08    0.09    0.01
# Test time         0.12    0.15    0.07    0.11    0.03
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.6921  0.6847  0.6873  0.6880  0.0030
# MAE (testset)     0.4982  0.4939  0.4953  0.4958  0.0018
# Fit time          0.10    0.07    0.07    0.08    0.02
# Test time         0.49    0.57    0.48    0.51    0.04
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.6490  0.6467  0.6494  0.6484  0.0012
# MAE (testset)     0.4619  0.4539  0.4617  0.4592  0.0037
# Fit time          0.09    0.14    0.21    0.15    0.05
# Test time         0.56    0.63    0.55    0.58    0.03
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithZScore on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.6525  0.6638  0.6500  0.6554  0.0060
# MAE (testset)     0.4573  0.4670  0.4608  0.4617  0.0040
# Fit time          0.14    0.14    0.13    0.14    0.00
# Test time         0.57    0.76    0.58    0.64    0.08
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBaseline on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.6578  0.6508  0.6428  0.6505  0.0061
# MAE (testset)     0.4706  0.4662  0.4630  0.4666  0.0031
# Fit time          0.15    0.14    0.14    0.14    0.00
# Test time         0.68    0.62    0.63    0.64    0.03
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.6309  0.6328  0.6299  0.6312  0.0012
# MAE (testset)     0.4619  0.4666  0.4632  0.4639  0.0020
# Fit time          1.85    1.96    2.22    2.01    0.15
# Test time         0.10    0.18    0.10    0.13    0.04
# Evaluating RMSE, MAE of algorithm NMF on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.6679  0.6754  0.6566  0.6666  0.0077
# MAE (testset)     0.4418  0.4443  0.4352  0.4405  0.0038
# Fit time          2.30    2.10    2.10    2.17    0.09
# Test time         0.08    0.08    0.08    0.08    0.00
# {'fit_time': (2.2954018115997314, 2.104573965072632, 2.0997989177703857),
#  'test_mae': array([0.44181879, 0.4443098 , 0.43522508]),
#  'test_rmse': array([0.6678841 , 0.67542534, 0.65663805]),
#  'test_time': (0.08130717277526855, 0.07795286178588867, 0.07904696464538574)}

# %%
trainset = data.build_full_trainset()
algo = NMF()
algo.fit(trainset)

# %%
from collections import defaultdict
ratings = defaultdict(list)
for contentId in iteractions.contentId.unique():
    ratings['contentId'].append(contentId)
    ratings['rating'].append(algo.predict(-9223121837663643404, contentId).est)
ratings = pd.DataFrame(ratings)
ratings = ratings.sort_values(by = 'rating', ascending = False)
print(ratings.shape)

user_read = iteractions[iteractions.personId == -9223121837663643404]
print(user_read.shape)
ratings = ratings[~ratings.contentId.isin(user_read.contentId)]
print(ratings.shape)
read_list = pd.merge(user_read, articles, how='left', on = 'contentId')
recom_list = pd.merge(ratings, articles, how='left', on = 'contentId')
# Out:
# (2984, 2)
# (43, 3)
# (2941, 2)

# %%
read_list
# Out:
#                personId            contentId  eventType_x   timestamp  \
# 0  -9223121837663643404 -8949113594875411859     1.000000  1462448930
# 1  -9223121837663643404 -8377626164558006982     1.000000  1473870933
# 2  -9223121837663643404 -8208801367848627943     1.000000  1469678235
# 3  -9223121837663643404 -8187220755213888616     1.000000  1467823363
# 4  -9223121837663643404 -7423191370472335463     3.169925  1478623412
# 5  -9223121837663643404 -7331393944609614247     1.000000  1463301395
# 6  -9223121837663643404 -6872546942144599345     1.000000  1487597538
# 7  -9223121837663643404 -6728844082024523434     1.000000  1485194633
# 8  -9223121837663643404 -6590819806697898649     1.000000  1485179372
# 9  -9223121837663643404 -6558712014192834002     1.584963  1464966720
# 10 -9223121837663643404 -6545872007932025533     1.584963  1474028337
# 11 -9223121837663643404 -6484638837208285334     1.000000  1461778643
# 12 -9223121837663643404 -5781461435447152359     1.000000  1461256156
# 13 -9223121837663643404 -5002383425685129595     1.584963  1467123962
# 14 -9223121837663643404 -4541461982704074404     1.000000  1467951625
# 15 -9223121837663643404 -4233177915193302509     1.000000  1463310537
# 16 -9223121837663643404 -4205346868684833897     1.584963  1465950308
# 17 -9223121837663643404 -3912939678517879962     1.000000  1464299862
# 18 -9223121837663643404 -3750879736572068916     1.000000  1464111011
# 19 -9223121837663643404 -2402288292108892893     1.584963  1487608319
# 20 -9223121837663643404  -730957269757756529     1.000000  1462275589
# 21 -9223121837663643404  -559964548932224920     1.584963  1469460909
# 22 -9223121837663643404  -447851796385928420     2.000000  1466187150
# 23 -9223121837663643404   834896074125772354     1.000000  1475419441
# 24 -9223121837663643404   921770761777842242     1.000000  1474001417
# 25 -9223121837663643404   943818026930898372     1.000000  1464055142
# 26 -9223121837663643404  1436883058900979473     1.000000  1469976528
# 27 -9223121837663643404  1469580151036142903     1.584963  1487127440
# 28 -9223121837663643404  3041906492387035176     1.000000  1463622449
# 29 -9223121837663643404  3180828616327439381     1.000000  1467813602
# 30 -9223121837663643404  3367026768872537336     1.000000  1473971457
# 31 -9223121837663643404  4419562057180692966     1.584963  1466862481
# 32 -9223121837663643404  4563606877148407012     1.000000  1463055007
# 33 -9223121837663643404  5087084654882097891     1.000000  1475673497
# 34 -9223121837663643404  5211673327552264703     1.000000  1475182869
# 35 -9223121837663643404  5293701842202310496     1.000000  1470071010
# 36 -9223121837663643404  6615662748793536194     1.000000  1470413693
# 37 -9223121837663643404  7229629480273331039     1.000000  1461211879
# 38 -9223121837663643404  7516228655554309785     1.000000  1462816920
# 39 -9223121837663643404  7734121175534200554     1.000000  1469052884
# 40 -9223121837663643404  8302949268716967655     2.321928  1484231249
# 41 -9223121837663643404  8310689940464940949     1.000000  1480955384
# 42 -9223121837663643404  8962537427807366481     1.584963  1465274456
#
#        eventType_y       authorPersonId      authorSessionId  \
# 0   CONTENT SHARED  1895326251577378793  6242109617183539580
# 1   CONTENT SHARED -5527145562136413747  5228941642832000454
# 2   CONTENT SHARED -3390049372067052505  2045534933671019150
# 3   CONTENT SHARED  1895326251577378793  6337372998984359835
# 4   CONTENT SHARED -4465926797008424436 -4234938118093547320
# 5   CONTENT SHARED -1032019229384696495  3697390468148831479
# 6   CONTENT SHARED -1393866732742189886 -6350745898785551312
# 7   CONTENT SHARED   801895594717772308  7194441186926042361
# 8   CONTENT SHARED -4465926797008424436 -7541317811547099244
# 9   CONTENT SHARED -1443636648652872475 -6631146006024713322
# 10  CONTENT SHARED -1402490765047599382 -9043465215175509636
# 11  CONTENT SHARED -1443636648652872475 -8312512943967547407
# 12  CONTENT SHARED -1032019229384696495 -6158072573466935774
# 13  CONTENT SHARED -3390049372067052505  2471338745689678750
# 14  CONTENT SHARED -1032019229384696495 -1187079779874414785
# 15  CONTENT SHARED  1895326251577378793  5829707946669210619
# 16  CONTENT SHARED -1443636648652872475  6340331642204025925
# 17  CONTENT SHARED -1032019229384696495 -3408618679466961471
# 18  CONTENT SHARED  1895326251577378793  4037412057375119343
# 19  CONTENT SHARED -4465926797008424436 -8412615285329455721
# 20  CONTENT SHARED  -331066625167168067 -6677202055740773123
# 21  CONTENT SHARED -6895155480127642372   909304340885309843
# 22  CONTENT SHARED  1895326251577378793 -4339659529018274221
# 23  CONTENT SHARED   -48161796606086482  -440734810322943341
# 24  CONTENT SHARED -2785363955043455312  2050770171372856452
# 25  CONTENT SHARED -6946355789336786528  4492969654113742216
# 26  CONTENT SHARED -1616903969205976623 -5530575741825489868
# 27  CONTENT SHARED -4465926797008424436  1603046601233039757
# 28  CONTENT SHARED -1387464358334758758 -3101989743624317360
# 29  CONTENT SHARED  1895326251577378793  6337372998984359835
# 30  CONTENT SHARED -3535274684588209118 -6495023147849651556
# 31  CONTENT SHARED -1032019229384696495  6917925448322846329
# 32  CONTENT SHARED -1032019229384696495 -7498496261095721452
# 33  CONTENT SHARED  3609194402293569455 -8059717165132702307
# 34  CONTENT SHARED  -331066625167168067  7167720501277973581
# 35  CONTENT SHARED -6067316262393890508  2245546651160341154
# 36  CONTENT SHARED  1895326251577378793  4845135633002089199
# 37  CONTENT SHARED -1032019229384696495 -6158072573466935774
# 38  CONTENT SHARED -3390049372067052505 -8729604331807064886
# 39  CONTENT SHARED  1748162647671155552 -2382936607572694307
# 40  CONTENT SHARED -4465926797008424436  5920817461981142302
# 41  CONTENT SHARED -1819083151847984459  3697326613788347092
# 42  CONTENT SHARED -1032019229384696495 -7696592431575292648
#
#                                       authorUserAgent authorRegion  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...           SP
# 5                                                 NaN          NaN
# 6   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...           MG
# 7   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_2...           MG
# 8   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...           SP
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
# 11                                                NaN          NaN
# 12                                                NaN          NaN
# 13                                                NaN          NaN
# 14                                                NaN          NaN
# 15                                                NaN          NaN
# 16                                                NaN          NaN
# 17                                                NaN          NaN
# 18                                                NaN          NaN
# 19  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...           SP
# 20                                                NaN          NaN
# 21                                                NaN          NaN
# 22                                                NaN          NaN
# 23                        Android - Native Mobile App           SP
# 24                                                NaN          NaN
# 25                                                NaN          NaN
# 26                                                NaN          NaN
# 27  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...           SP
# 28                                                NaN          NaN
# 29                                                NaN          NaN
# 30                                                NaN          NaN
# 31                                                NaN          NaN
# 32                                                NaN          NaN
# 33  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...           SP
# 34  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...           MG
# 35                                                NaN          NaN
# 36                                                NaN          NaN
# 37                                                NaN          NaN
# 38                                                NaN          NaN
# 39                                                NaN          NaN
# 40  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...           SP
# 41  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1...           SP
# 42                                                NaN          NaN
#
#    authorCountry contentType  \
# 0            NaN        HTML
# 1            NaN        HTML
# 2            NaN        HTML
# 3            NaN        HTML
# 4             BR        HTML
# 5            NaN        HTML
# 6             BR        HTML
# 7             BR        HTML
# 8             BR        HTML
# 9            NaN        HTML
# 10           NaN        HTML
# 11           NaN        HTML
# 12           NaN        HTML
# 13           NaN        HTML
# 14           NaN        HTML
# 15           NaN        HTML
# 16           NaN        HTML
# 17           NaN        HTML
# 18           NaN        HTML
# 19            BR        HTML
# 20           NaN        HTML
# 21           NaN        HTML
# 22           NaN        HTML
# 23            BR        HTML
# 24           NaN        HTML
# 25           NaN        HTML
# 26           NaN        HTML
# 27            BR        HTML
# 28           NaN        HTML
# 29           NaN        HTML
# 30           NaN        HTML
# 31           NaN        HTML
# 32           NaN        HTML
# 33            BR        HTML
# 34            BR        HTML
# 35           NaN        HTML
# 36           NaN        HTML
# 37           NaN        HTML
# 38           NaN        HTML
# 39           NaN        HTML
# 40            BR        HTML
# 41            BR        HTML
# 42           NaN        HTML
#
#                                                   url  \
# 0   http://m.folha.uol.com.br/mercado/2016/05/1766...
# 1   https://hbr.org/2016/09/bad-writing-is-destroy...
# 2   http://www.geekwire.com/2016/ray-kurzweil-worl...
# 3   http://www.mckinsey.com/industries/high-tech/o...
# 4   https://medium.com/android-dev-br/espresso-int...
# 5   http://www.businessinsider.com/amit-singh-jump...
# 6   https://medium.com/@husayn.hakeem/my-experienc...
# 7             http://merowing.info/2017/01/seniority/
# 8   https://medium.com/android-dev-br/listas-com-r...
# 9   http://arstechnica.com/tech-policy/2016/06/goo...
# 10  https://medium.com/chris-messina/silicon-valle...
# 11  http://www.greenbot.com/article/3058745/androi...
# 12  https://gmail.googleblog.com/2016/04/inbox-by-...
# 13  http://www.mckinsey.com/global-themes/leadersh...
# 14  http://www.theverge.com/2016/7/7/12111028/micr...
# 15  http://computerworld.com.br/governo-brasileiro...
# 16  http://techcrunch.com/2016/06/14/google-launch...
# 17  http://techcrunch.com/2016/05/26/jury-finds-go...
# 18  http://www.businessinsider.com/apple-is-the-ne...
# 19  http://www.codeatest.com/como-testar-excecoes-...
# 20  https://medium.com/@vilucas/por-que-a-limita%C...
# 21  http://jeffsegurosonline.blogspot.com.br/2016/...
# 22  http://www.mobiletime.com.br/17/06/2016/flyhel...
# 23  http://venturebeat.com/2016/10/02/so-you-want-...
# 24  http://www.telegraph.co.uk/technology/2016/09/...
# 25  http://exame.abril.com.br/pme/noticias/inovado...
# 26  http://www.mckinseyonmarketingandsales.com/the...
# 27  https://dev.to/raddikx/dont-document-your-code...
# 28  http://m.tecmundo.com.br/google/104969-whatsap...
# 29  http://computerworld.com.br/governo-define-cro...
# 30  http://br.blog.trello.com/melhore-a-comunicaca...
# 31  https://techcrunch.com/2016/06/25/latin-americ...
# 32  http://www.wired.com/2016/05/youtubes-new-mess...
# 33  http://googlediscovery.com/2016/10/04/google-p...
# 34  https://cloudplatform.googleblog.com/2016/09/G...
# 35  https://contently.com/strategist/2016/07/29/ca...
# 36  http://computerworld.com.br/especial-o-papel-d...
# 37  http://www.businessinsider.com/organization-ra...
# 38  http://www.mckinsey.com/industries/financial-s...
# 39  http://www.meioemensagem.com.br/home/comunicac...
# 40  https://hackernoon.com/what-makes-a-good-andro...
# 41  https://medium.com/inloop/android-process-kill...
# 42  http://www.wsj.com/articles/why-its-time-to-ta...
#
#                                                 title  \
# 0   No Brasil, '25% dos celulares ainda são 'Burro...
# 1   Bad Writing Is Destroying Your Company's Produ...
# 2   Ray Kurzweil: The world isn't getting worse - ...
# 3   Organizing for digital acceleration: Making a ...
# 4   Espresso Intents: não é magia, é tecnologia! -...
# 5   Here's proof that Google is getting serious ab...
# 6   My experience with Google's Associate Android ...
# 7                                           Seniority
# 8            Listas com RecyclerView - Android Dev BR
# 9   Google's fair use victory is good for open source
# 10  Why Silicon Valley is all wrong about Apple's ...
# 11  5 awesome Google Keep features you aren't usin...
# 12  Inbox by Gmail: a better way to keep track of ...
# 13                         Changing change management
# 14  Exclusive: Why Microsoft is betting its future...
# 15  Governo brasileiro cria manual para contrataçã...
# 16  Google launches Springboard, an AI-powered ass...
# 17  Jury finds Google's implementation of Java in ...
# 18  No, Apple isn't the next BlackBerry - it's the...
# 19  Como testar exceções em Java com o JUnit - Cod...
# 20  Por que a limitação da banda larga é uma forma...
# 21                      Jeff Seguros: SEGUROS E GAMES
# 22  MOBILE TIME - FlyHelo: app permite compartilha...
# 23                      So you want to sell to banks?
# 24  Pixelated photos and licence plates can be unb...
# 25  Inovador, Nubank ganha prêmio no Vale do Silíc...
# 26                    The future of the shopping mall
# 27  Don't document your code. Code your documentat...
# 28        O WhatsApp do Google chegou e se chama Allo
# 29  Governo define cronograma para plano nacional ...
# 30  Seja esperto no trabalho: Melhore a comunicaçã...
# 31  Latin America's chronic inefficiency could dri...
# 32  YouTube's New Messenger Means You'll Never Hav...
# 33  Google Pixel, o primeiro smartphone feito pelo...
# 34  Google Cloud Platform sets a course for new ho...
# 35               Can Accenture Take Over Advertising?
# 36  Especial: O papel dos grandes provedores de TI...
# 37  An independent organization just ranked Google...
# 38        A digital crack in banking's business model
# 39  "Consultorias promovem a desvalorização do nos...
# 40      What makes a good (Android) Software Engineer
# 41  Android process death - and the (big) implicat...
# 42  Why It's Time to Take Google's PC Operating Sy...
#
#                                                  text lang
# 0   Divulgação O ex-jogador de futebol Tostão, don...   pt
# 1   A hidden source of friction is slowing your co...   en
# 2   Ray Kurzweil, the author, inventor, computer s...   en
# 3   By adopting a digital product management model...   en
# 4   Se você leu meu último artigo sobre Testes uni...   pt
# 5   Business Insider/Julie Bort Amit Singh, who ho...   en
# 6   In this article I talk about my personal exper...   en
# 7   People use different words to classify Enginee...   en
# 8   Lista simples O primeiro passo é colocar o Rec...   pt
# 9   Pamela Samuelson is a longtime professor of IP...   en
# 10  So you think Apple is a tech company? No, you'...   en
# 11  Google Keep is not preinstalled on all phones,...   en
# 12  Life can get really busy. Inboxes too. Just th...   en
# 13  Research tells us that most change efforts fai...   en
# 14  After losing on mobile, can Microsoft win the ...   en
# 15  O Ministério do Planejamento, Orçamento e Gest...   pt
# 16  Google has unwrapped two significant announcem...   en
# 17  Software developers can breathe a massive sigh...   en
# 18  Business Insider Over the weekend, long-time i...   en
# 19  Introdução Neste post vou mostrar de forma suc...   pt
# 20  Por que a limitação da banda larga é uma forma...   pt
# 21  LANÇADO em apenas três países até agora, já vi...   pt
# 22  FlyHelo: app permite compartilhamento de jatos...   pt
# 23  If you ask almost any early-stage B2B FinTech ...   en
# 24  Pixelated or blurred photographs could be at r...   en
# 25  São Paulo - O Nubank , startup brasileira que ...   pt
# 26  Officially shopping malls are defined as "one ...   en
# 27  This is one of the great discussions among dev...   en
# 28  A Google acabou de anunciar durante o evento G...   pt
# 29  Ricardo Rivera, gerente setorial das indústria...   pt
# 30  Seja Esperto no Trabalho: Melhore a Comunicaçã...   pt
# 31  After 45 minutes on the phone with a travel ag...   en
# 32  We've all had it happen: You're talking with a...   en
# 33  O Google anunciou o Pixel, primeiro smartphone...   pt
# 34  As we officially move into the Google Cloud er...   en
# 35  Last month, in New York City's Soho neighborho...   en
# 36  Durante o mês de agosto, o mundo todo estará c...   pt
# 37  Fortune Global Forum Amazon may be the 800-pou...   en
# 38  Low-cost attackers are targeting customers in ...   en
# 39  Bárbara Sacchitiello19 de julho de 2016 - 13h0...   pt
# 40  For the past five years, I have been building ...   en
# 41  With more developers using Dependency Injectio...   en
# 42  For most of my working life, I've used Macs at...   en

# %%
recom_list
# Out:
#                 contentId    rating     timestamp       eventType  \
# 0    -4262964715347041233  2.950712  1.467681e+09  CONTENT SHARED
# 1    -2402157201203242566  2.826674  1.466519e+09  CONTENT SHARED
# 2     3739926497176994524  2.737724  1.480423e+09  CONTENT SHARED
# 3     4909630283317268181  2.696768  1.486125e+09  CONTENT SHARED
# 4     3801064060797809024  2.635400  1.462365e+09  CONTENT SHARED
# 5     -340541651592032197  2.574802  1.484310e+09  CONTENT SHARED
# 6    -4228415104574264137  2.465933  1.465842e+09  CONTENT SHARED
# 7     9136323715291453594  2.458278  1.465919e+09  CONTENT SHARED
# 8    -3351652027149912881  2.413429  1.478348e+09  CONTENT SHARED
# 9     2415534163825594672  2.366363  1.461339e+09  CONTENT SHARED
# 10    1618055575277164008  2.357421  1.465842e+09  CONTENT SHARED
# 11   -8728075196312712282  2.348800  1.470779e+09  CONTENT SHARED
mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...           SP
# 6                                                   NaN          NaN
# 7                                                   NaN          NaN
# 8     Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...           SP
# 9                                                   NaN          NaN
# 10                                                  NaN          NaN
# 11                                                  NaN          NaN
# 12                                                  NaN          NaN
# 13                                                  NaN          NaN
# 14                                                  NaN          NaN
# 15                                                  NaN          NaN
# 16                                                  NaN          NaN
# 17                                                  NaN          NaN
# 18                                                  NaN          NaN
# 19                                                  NaN          NaN
# 20                                                  NaN          NaN
# 21    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_2...           GA
# 22    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6...           NJ
# 23                                                  NaN          NaN
# 24                                                  NaN          NaN
# 25                                                  NaN          NaN
# 26                                                  NaN          NaN
# 27                                                  NaN          NaN
# 28                                                  NaN          NaN
# 29    Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...           MG
# ...                                                 ...          ...
# 2911  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...           SP
# 2912                                                NaN          NaN
# 2913                                                NaN          NaN
# 2914                                                NaN          NaN
# 2915                                                NaN          NaN
# 2916                                                NaN          NaN
# 2917                                                NaN          NaN
# 2918                                                NaN          NaN
# 2919                                                NaN          NaN
# 2920                                                NaN          NaN
# 2921                                                NaN          NaN
# 2922                                                NaN          NaN
# 2923                                                NaN          NaN
# 2924                                                NaN          NaN
# 2925  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...           SP
# 2926                                                NaN          NaN
# 2927                                                NaN          NaN
# 2928  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...           SP
# 2929                                                NaN          NaN
# 2930                                                NaN          NaN
# 2931  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...           SP
# 2932                                                NaN          NaN
# 2933                                                NaN          NaN
# 2934  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...           SP
# 2935  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...           SP
# 2936                                                NaN          NaN
# 2937                                                NaN          NaN
# 2938                                                NaN          NaN
# 2939                                                NaN          NaN
# 2940                        Android - Native Mobile App           SP
#
#      authorCountry contentType  \
# 0              NaN        HTML
# 1              NaN        HTML
# 2               BR        HTML
# 3               BR        HTML
# 4              NaN        HTML
# 5               BR        HTML
# 6              NaN        HTML
# 7              NaN        HTML
# 8               BR        HTML
# 9              NaN        HTML
# 10             NaN        HTML
# 11             NaN        HTML
# 12             NaN        HTML
# 13             NaN        HTML
# 14             NaN        HTML
# 15             NaN        HTML
# 16             NaN        HTML
# 17             NaN        HTML
# 18             NaN        HTML
# 19             NaN        HTML
# 20             NaN        HTML
# 21              US        HTML
# 22              US        HTML
# 23             NaN        HTML
# 24             NaN        HTML
# 25             NaN        HTML
# 26             NaN        HTML
# 27             NaN        HTML
# 28             NaN        HTML
# 29              BR        HTML
# ...            ...         ...
# 2911            BR        HTML
# 2912           NaN        HTML
# 2913           NaN        HTML
# 2914           NaN        HTML
# 2915           NaN        HTML
# 2916           NaN        HTML
# 2917           NaN        HTML
# 2918           NaN        HTML
# 2919           NaN        HTML
# 2920           NaN        HTML
# 2921           NaN        HTML
# 2922           NaN        HTML
# 2923           NaN        HTML
# 2924           NaN        HTML
# 2925            BR        HTML
# 2926           NaN        HTML
# 2927           NaN        HTML
# 2928            BR        HTML
# 2929           NaN        HTML
# 2930           NaN        HTML
# 2931            BR        HTML
# 2932           NaN        HTML
# 2933           NaN        HTML
# 2934            BR        HTML
# 2935            BR        HTML
# 2936           NaN        HTML
# 2937           NaN        HTML
# 2938           NaN        HTML
# 2939           NaN        HTML
# 2940            BR        HTML
#
#                                                     url  \
# 0           https://marketing.knect365.com/intrapreneur
# 1     https://techcrunch.com/2016/06/21/number26-rai...
# 2939  http://www.intelbras.com.br/empresarial/wi-fi/...
# 2940  http://conteudo.startse.com.br/mercado/lucas-b...
#
#                                                   title  \
# 0                         Corporate Intrapreneur Summit
# 1     Number26 raises another $40 million for its vi...
# 2                                   Resenha - A Chegada
# 3     Como o Banco do Brasil está inovando e incenti...
# 4                        How Green Was My Valley (1941)
# 5     Relating a Problem Definition to IoT Architect...
# 6     Up your app's sharing game with DirectShare - ...
# 7     How to Improve 8 Major Problem Areas for Japan...
# 8     Feather: A Fast On-Disk Format for Data Frames...
# 9                                          Hintjens.com
# 10           Lista tem 15 dicas para Google Docs; teste
# 11    Soylent's new drink will replace your breakfas...
# 12    Shopping app Spring's redesign could be a game...
# 13                  Building more accessible technology
# 14               The need to lead in data and analytics
# 15    Enable secure mode on your web product | Inter...
# 16    Progressive Web App - first introduced on Goog...
# 17    Salesforce buys Demandware for $2.8B, taking a...
# 18    Startup uses deep learning to let you shop for...
# 19                                     Incendies (2010)
# 20    Running GV sprints inside corporates - learn f...
# 21    Little girls doubt that women can be brilliant...
# 22    Indian outsourcing specialists must reboot the...
# 23                        Designing smart notifications
# 24    PwC faz virada digital e já fatura US$ 1 bilhã...
# 25             Presenting to the Boss(es) | Pluralsight
# 26    One weird trick that will change the way you c...
# 27    An operating model for company-wide agile deve...
# 28        Practical VPC Design - AWS Startup Collection
# 29     Swift Top 10 Articles For The Past Year (v.2017)
# ...                                                 ...
# 2911  BMW mostra conceito de tela touch flutuante em...
# 2912  Irresistível: cebola recheada com carne moída ...
# 2913  Bolt teria recebido uns R$ 12 milhões por camp...
# 2914  LATIN INNOVATION BONANZA | New South & Central...
# 2915               Domain Driven Design e Microservices
# 2916                                gotwarlost/istanbul
# 2917  O Brasil das fintechs: conheça startups nacion...
# 2918  Astronomia: A semana de Marte - Mensageiro Sid...
# 2919  FH fecha contrato de OEM com SAP para entrega ...
# 2920  Desinformação (até do Senado) faz motoristas a...
# 2921  Why Performance Matters, Part 2: Perception Ma...
# 2922  How Etsy Does Continuous Integration for Mobil...
# 2923  Madrid encontra forma divertida - e colorida -...
# 2924  Google will show AMP URLs before App deep link...
# 2925  The Complete Google Analytics Audit Checklist ...
# 2926  Vivo cria laboratório de dados para impulsiona...
# 2927  DTCC and Digital Asset Holdings to Test Blockc...
# 2928     Google tag manager Workspaces - Como funciona?
# 2929         Como nasce um carro. | Volkswagen Magazine
# 2930  Grupo Abril oficializa novo posicionamento - M...
# 2931  Gestão de Dados: 10 questões básicas sobre seu...
# 2932  Unilever cria e-commerce para lojas de bairro ...
# 2933  Após 9 meses de operação e sucesso meteórico, ...
# 2934  Uber se prepara para lançar serviço de deliver...
# 2935  Improvements coming to the Google Analytics de...
# 2936  Inteligência Analítica: como a Disney utiliza ...
# 2937  P&G cancela verba para anúncios segmentados no...
# 2938  Cultura de Web Analytics e Métricas, o que é? ...
# 2939                                        HotSpot 300
# 2940  Fusão de startups cria uma das maiores de tecn...
#
#                                                    text lang
# 0     The 2016 Corporate Intrapreneur Summit, produc...   en
# 1     Berlin-based startup Number26 just raised a $4...   en
# 2     Supondo que haja vida inteligente no Universo ...   pt
# 3     Acontece esse semana em São Paulo, a décima ed...   pt
# 4     Storyline Life is hard in a Welsh mining town ...   en
# 5     Lets face it, the largest function within IoT ...   en
# 6     Up your app's sharing game with Direct Share A...   en
# 7     Have you hit a big ol' wall while learning Jap...   en
# 8     Wes McKinney, Software Engineer, Cloudera Hadl...   en
# 9     First: blog:1 Elegant Little Pieces Edited: by...   en
# 10    O Google Docs ou Documentos, em português, é o...   pt
# 11    Soylent, the famed meal replacement that went ...   en
# 12    Back in 2013, Alan Tisch, the CEO of the shopp...   en
# 13    Nearly 20 percent of the U.S. population will ...   en
# 14    In a new survey, executives say senior-leader ...   en
# 15    We strongly encourage all Intercom customers t...   en
# 16    airberlin is delighted to be the first airline...   en
# 17    Salesforce made its name originally with cloud...   en
# 18    Computer vision and image recognition, aka the...   en
# 19    Top Rated Movies #153 | Nominated for 1 Oscar....   en
# 20    Running GV sprints inside corporates - learn f...   en
# 21    WASHINGTON - Can women be brilliant? Little gi...   en
# 22    COMPUTERS slow as they age, and before long mu...   en
# 23    Designing smart notifications My phone buzzed....   en
# 24    Transformação Quando se imagina o dia a dia de...   pt
# 25    This course will help you prepare for and make...   en
# 26    This is a presentation delivered to the Squiz ...   en
# 27    Organizations are succeeding with agile softwa...   en
# 28    Practical VPC Design 301 level guidance from a...   en
# 29    For the past year , we've ranked nearly 9,000 ...   en
# ...                                                 ...  ...
# 2911  A BMW divulgou novos detalhes de seu novo conc...   pt
# 2912  O Canal Tempero Caseiro preparou essa delicios...   pt
# 2913  Negócios Bolt teria recebido uns R$ 12 milhões...   pt
# 2914  Regular readers will know the secret at the he...   en
# 2915  No QCon Londres 2016, Eric Evans, autor de Dom...   pt
# 2916  istanbul - Yet another JS code coverage tool t...   en
# 2917  SÃO PAULO - Já faz algum tempo que as startups...   pt
# 2918  Nasa/ESA A semana que começa traz Marte para p...   pt
# 2919  Colaboração A FH firmou contrato de OEM (sigla...   pt
# 2920  As notícias vieram rápido, e já criaram o pâni...   pt
# 2921  Time can be analyzed from two different points...   en
# 2922  Nassim Kammah , engineer at Etsy , explained t...   en
# 2923  As faixas de pedestres estão presentes na roti...   pt
# 2924  Google will now have AMP trump App URLs in the...   en
# 2925  It is critical to make sure you are basing you...   en
# 2926  A Vivo pretende intensificar o uso de informaç...   pt
# 2927  Depository Trust & Clearing Corp. (DTCC), a fi...   en
# 2928  Como muitos perceberam o google tag manager mu...   pt
# 2929  Quem costuma proferir essa frase é Luiz Albert...   pt
# 2930  Luiz Gustavo Pacete11 de agosto de 2016 - 12h0...   pt
# 2931  1 – Afinal, qual o termo correto: Gestão de Da...   pt
# 2932  São Paulo - A Unilever lançou um comércio elet...   pt
# 2933  Após longo duelo no mercado chinês, o Uber dec...   pt
# 2934  São Paulo - Uber está se preparando para lança...   pt
# 2935  Over the last ten years, Google Analytics has ...   en
# 2936  Inteligência Analítica Na década de 1960, o so...   pt
# 2937  No mesmo dia em que o Facebook confirmou uma a...   pt
# 2938  Muitas empresas ainda não possuem uma cultura ...   pt
# 2939  Pressione TAB para navegar pela página Especif...   pt
# 2940  Em 2017, a solução deve gerar uma economia de ...   pt
#
# [2941 rows x 14 columns]
